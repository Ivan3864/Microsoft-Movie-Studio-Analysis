# %% [markdown]
# # Project Overview -(Phase 1 Project)
# ### Using exploratory data analysis to generate insights for a business stakeholder.
#
# ## 1. The Business problem
# ### a) Specifying the Business problem
# > Microsoft sees all the big companies creating original video content and they want to get in on the fun.
# > They have decided to create a new movie studio, but they don’t know anything about creating movies.
#
# >**Problem Statement:** You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# ### b) Defining the Metric for Success
# To define the metric for success in this project, the following factors should be considered:
#
# 1. `Box Office Revenue` : The primary metric for success in the movie industry is the box office revenue generated by a film. This analysis should aim to identify the types of films that have been most successful in terms of generating high box office revenue.
#
# 2. `Audience Reception` : While revenue is crucial, the audience's reception and satisfaction are also important indicators of success. Factors such as ratings, reviews, and audience engagement can provide insights into the types of films that resonate well with viewers.
#
# 3. `Return on Investment (ROI)`: Another important metric is the return on investment, which measures the profitability of a film. It is calculated by dividing the film's total revenue by its production budget. Identifying films with high ROI can provide valuable insights for Microsoft's new movie studio to prioritize investments.
#
# Overall, success can be measured by identifying the most profitable film genres, optimizing ROI, satisfying audience preferences, gaining market share, and outperforming competitors.
#
# ### c) Understanding the context
# In the given context, Microsoft has decided to venture into the movie industry and create its own movie studio. However, they lack knowledge and experience in the field of movie production.
#
# The objective is to analyze the existing movie landscape and provide actionable insights to the head of Microsoft's new movie studio. These insights will help Microsoft make informed decisions on the types of films they should create to maximize their chances of success.
#
#
# ### d) Recording the Experimental Design
#
#  The  following experimental design will be followed in order to conduct the exploratory data analysis and generate insights for Microsoft's new movie studio:
#
# 1. `Data Collection`: Gathering of  relevant data on movie box office performance, including information on film genres, box office revenue, production budgets, ratings, and other relevant variables.
#
# 2. `Data Cleaning and Preparation`: Cleaning the collected data to ensure its quality and reliability. This step involves handling missing values, removing duplicates, standardizing variables, and transforming data if necessary.
#
# 3. `Data Exploration and Descriptive Analysis`: Performing exploratory data analysis to gain initial insights into the dataset. This can include examining the distribution of box office revenue, analyzing the relationship between revenue and different variables (e.g., genres, production budgets), identifying trends or patterns in film performance, and summarizing descriptive statistics.
#
# 4. `Analysis and Visualization` : Utilizing appropriate statistical techniques and visualization tools to analyze the data and uncover insights. Explore the relationships between different variables, identify correlations or trends, and visualize the findings to facilitate understanding and interpretation.
#
# 6. `Insights Generation` : Based on the analysis results, generating actionable insights that Microsoft's movie studio can be used to make informed decisions. Identifying  the film genres that have performed well in terms of revenue and ROI, highlight audience preferences and trends, and suggest potential opportunities or gaps in the market.
#
# 7. `Reporting and Presentation` : Preparing a comprehensive report or presentation summarizing the findings, insights, and recommendations.
# using visualizations, charts, and tables to present the results effectively.

# %% [markdown]
# ## 2. Reading The data
# For this analysis We will be using Three datasets
#
# 1. `title.basics.csv` - To get to know various Movies and their genres
# 2. `tmdb.movies.csv` -To get to know various Movies and their popularity
# 3. `tn.movie_budgets.csv` - To get the revenue and production budget

# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset1= pd.read_csv('Data-files/title.basics.csv')
dataset2= pd.read_csv('Data-files/tmdb.movies.csv')
dataset3= pd.read_csv('Data-files/tn.movie_budgets.csv')

# %% [markdown]
# ## 3. Checking Our datasets
# We will be checking our three datasets to get a deeper understanding of what they entail

# %%
# Determining the no. of records in all our datasets
num_records1 = dataset1.shape[0]
print("Number of records in Dataset 1 is:", num_records1)
num_records2 = dataset2.shape[0]
print("Number of records in Dataset 2 is:", num_records2)
num_records3 = dataset3.shape[0]
print("Number of records in Dataset 3 is:", num_records3)
# Out:
# Number of records in Dataset 1 is: 146144
# Number of records in Dataset 2 is: 26517
# Number of records in Dataset 3 is: 5782

# %%
# Previewing the top and bottom of our datasets
dataset1
# Out:
#            tconst                                primary_title
# 0       tt0063540                                    Sunghursh  \
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year
# 0                                         Sunghursh        2013  \
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
dataset2
# Out:
#        Unnamed: 0            genre_ids      id original_language
# 0               0      [12, 14, 10751]   12444                en  \
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19  \
# ...

# %%
dataset3
# Out:
#       id  release_date                                        movie
# 0      1  Dec 18, 2009                                       Avatar  \
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# Checking whether each column has an appropriate datatype
column_dtypes1 = dataset1.dtypes
print(column_dtypes1)
# Out:
# tconst              object
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
column_dtypes2 = dataset2.dtypes
print(column_dtypes2)
# Out:
# Unnamed: 0             int64
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
column_dtypes3 = dataset3.dtypes
print(column_dtypes3)
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %% [markdown]
# ## 4. Performing Data cleaning
# >In this section we will embark on the  process of identifying and correcting or removing errors, inconsistencies, and inaccuracies in a dataset to ensure its quality and reliability. It will involve various operations such as handling missing values, handling outliers, correcting data types, removing duplicates, and standardizing data.
#
# ### a). Cleaning Dataset1

# %%
# Handling missing values on Dataset 1
dataset1.isna().sum()
# Out:
# Title      0
# Year       0
# Runtime    0
# Genre      0
# dtype: int64

# %%
# Remove rows with missing values
dataset1 = dataset1.dropna()

# Fill missing values with a specific value or strategy
dataset1['runtime_minutes'] = dataset1['runtime_minutes'].fillna(dataset1['runtime_minutes'].mean())

# %%
# Data type corrections
dataset1.dtypes
dataset1['start_year'] = dataset1['start_year'].astype(int)

# %%
dataset1.dtypes
# Out:
# tconst              object
# primary_title       object
# original_title      object
# start_year           int32
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
# Checking for Data Consistency
# Extracting the first genre from the "genres" column
dataset1['first_genre'] = dataset1['genres'].str.split(',', expand=True)[0]

# %%
#Dropping original title
dataset1 = dataset1.drop('original_title', axis=1)

# %%
# Checking for duplicates
duplicates = dataset1.duplicated()
# Print the duplicate rows
duplicate_rows = dataset1[duplicates]
print("Duplicate rows:")
print(duplicate_rows)

# Print the number of duplicate rows
num_duplicates = len(duplicate_rows)
print("Number of duplicate rows:", num_duplicates)
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [tconst, primary_title, original_title, start_year, runtime_minutes, first_genre]
# Index: []
# Number of duplicate rows: 0

# %%
# Dropping tconst
dataset1 = dataset1.drop(columns=['tconst'])

# %%
# Renaming the column Names
dataset1 = dataset1.rename(columns={'primary_title': 'Title', 'start_year': 'Year', 'runtime_minutes': 'Runtime', 'first_genre': 'Genre'})

# %%
#Previewing the final cleaned dataset1
dataset1
# Out:
#                                                     Title  Year  Runtime
# 0                                               Sunghursh  2013    175.0  \
# 1                         One Day Before the Rainy Season  2019    114.0
# 2                              The Other Side of the Wind  2018    122.0
# 4                                The Wandering Soap Opera  2017     80.0
# 5                                             A Thin Life  2018     75.0
# ...                                                   ...   ...      ...
# 146134                                         Drømmeland  2019     72.0
# 146135                                      The Rehearsal  2019     51.0
# 146136  Illenau - die Geschichte einer ehemaligen Heil...  2017     84.0
# 146137                                          Safeguard  2019     90.0
# 146139                                Kuambil Lagi Hatiku  2019    123.0
#
#               Genre
# 0            Action
# 1         Biography
# 2             Drama
# ...

# %% [markdown]
# ### b). Cleaning Dataset2

# %%
# Checking for missing values
dataset2.isnull().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
# Check for duplicates
duplicates = dataset2.duplicated(keep=False)
if duplicates.any():
    print("Duplicate rows found! Dropping duplicates...")
    dataset2 = dataset2[~duplicates]
    print("Duplicates removed.")
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
# Droping unnecessary columns
columns_to_drop = ['Unnamed: 0', 'genre_ids', 'id', 'title', 'vote_average',]
dataset2 = dataset2.drop(columns=columns_to_drop)

# %%
# Dropping the vote_count
columns_to_drop = ['vote_count']
dataset2 = dataset2.drop(columns=columns_to_drop)

# %%
# Rearrange the columns
desired_order = ['original_title', 'original_language', 'release_date', 'popularity']
dataset2 = dataset2[desired_order + [col for col in dataset2.columns if col not in desired_order]]

# %%
#Renaming The column Names
# Define the new column names
new_column_names = {
    'original_title': 'Movie Title',
    'original_language': 'Original Language',
    'release_date': 'Release Date',
    'popularity': 'Popularity'
}

# Rename the columns
dataset2 = dataset2.rename(columns=new_column_names)

# %%
#Checking for any abnomarlities
popularity_stats = dataset2['Popularity'].describe()
print(popularity_stats)
# Out:
# count    26517.000000
# mean         3.130912
# std          4.355229
# min          0.600000
# 25%          0.600000
# 50%          1.374000
# 75%          3.694000
# max         80.773000
# Name: Popularity, dtype: float64

# %%
#Checking the final Dataset2
dataset2
# Out:
#                                         Movie Title Original Language
# 0      Harry Potter and the Deathly Hallows: Part 1                en  \
# 1                          How to Train Your Dragon                en
# 2                                        Iron Man 2                en
# 3                                         Toy Story                en
# 4                                         Inception                en
# ...                                             ...               ...
# 26512                         Laboratory Conditions                en
# 26513                               _EXHIBIT_84xxx_                en
# 26514                                  The Last One                en
# 26515                                  Trailer Made                en
# 26516                                    The Church                en
#
#       Release Date  Popularity
# 0       2010-11-19      33.533
# 1       2010-03-26      28.734
# ...

# %% [markdown]
# ### c). Cleaning Dataset3

# %%
dataset3
# Out:
#       id  release_date                                        movie
# 0      1  Dec 18, 2009                                       Avatar  \
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
#Checking for missing data
dataset3.isnull().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# Check for duplicates
duplicates3 = dataset3.duplicated(keep=False)
if duplicates.any():
    print("Duplicate rows found! Dropping duplicates...")
    dataset3 = dataset3[~duplicates]
    print("Duplicates removed.")
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
# Removing Currency Symbols and Commas
import re

# Define a function to remove non-numeric characters and convert to integers
def clean_numeric_value(value):
    cleaned_value = re.sub(r'[^0-9]', '', value)
    return int(cleaned_value) if cleaned_value else None

# Apply the clean_numeric_value function to the specified columns
dataset3['production_budget'] = dataset3['production_budget'].apply(clean_numeric_value)
dataset3['domestic_gross'] = dataset3['domestic_gross'].apply(clean_numeric_value)
dataset3['worldwide_gross'] = dataset3['worldwide_gross'].apply(clean_numeric_value)

# %%
#Converting 'release_date' to DateTime:
dataset3['release_date'] = pd.to_datetime(dataset3['release_date'])

# %%
#Dropping columns
dataset3 = dataset3.drop('id', axis=1)

# %%
#Re-arranging the columns
dataset3 = dataset3[['movie', 'release_date', 'production_budget', 'domestic_gross', 'worldwide_gross']]

# %%
#Renaming the column names
dataset3 = dataset3.rename(columns={
    'movie': 'Movie',
    'release_date': 'Release Date',
    'production_budget': 'Production Budget',
    'domestic_gross': 'Domestic Gross',
    'worldwide_gross': 'Worldwide Gross'
})

# %%
#Previewing the cleaned dataset
dataset3
# Out:
#                                             Movie Release Date
# 0                                          Avatar   2009-12-18  \
# 1     Pirates of the Caribbean: On Stranger Tides   2011-05-20
# 2                                    Dark Phoenix   2019-06-07
# 3                         Avengers: Age of Ultron   2015-05-01
# 4               Star Wars Ep. VIII: The Last Jedi   2017-12-15
# ...                                           ...          ...
# 5777                                       Red 11   2018-12-31
# 5778                                    Following   1999-04-02
# 5779                Return to the Land of Wonders   2005-07-13
# 5780                         A Plague So Pleasant   2015-09-29
# 5781                            My Date With Drew   2005-08-05
#
#       Production Budget  Domestic Gross  Worldwide Gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# ...

# %% [markdown]
# # 5. Exploratory Analysis On The datsets
# >In this stage we are going to provide initial insights into the data, guide subsequent steps in the analysis, and assist in formulating a solution to our problem.
#
# ### a) Exploratory Analysis On Dataset1
# We will start with the first dataset which is dataset1 (`title.basics.csv`)for us to know various Movies and their genres

# %%
#providing a summary of the numerical columns in the dataset
dataset1.describe()
# Out:
#                 Year        Runtime
# count  112232.000000  112232.000000
# mean     2014.402078      86.261556
# std         2.639042     167.896646
# min      2010.000000       1.000000
# 25%      2012.000000      70.000000
# 50%      2014.000000      87.000000
# 75%      2017.000000      99.000000
# max      2022.000000   51420.000000

# %%
#Genre Analysis
genre_counts = dataset1['Genre'].value_counts()
print(genre_counts)
# Out:
# Genre
# Documentary    33766
# Drama          24535
# Comedy         17481
# Action          8110
# Biography       7564
# Horror          4974
# Adventure       4243
# Crime           3315
# Thriller        1931
# Animation       1430
# Romance          884
# Family           774
# Mystery          652
# Fantasy          646
# Sci-Fi           535
# Music            436
# History          266
# Musical          256
# Sport            210
# Western          101
# War               61
# Reality-TV        31
# Talk-Show         13
# News              10
# Adult              6
# Game-Show          1
# Short              1
# Name: count, dtype: int64

# %%
# Out:
# Genre
# Documentary    33766
# Drama          24535
# Comedy         17481
# Action          8110
# Biography       7564
# Horror          4974
# Adventure       4243
# Crime           3315
# Thriller        1931
# Animation       1430
# Name: count, dtype: int64

# %%
#Visualizing the frequency distribution of genres
genre_counts = dataset1['Genre'].value_counts()
plt.figure(figsize=(8, 4))
plt.bar(genre_counts.index, genre_counts.values)
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Genre Frequency Distribution')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the Above Chart we can see that the Genre appearing the most is Documentaries

# %% [markdown]
# Yearly Trend: Analyzing the trend in movie production over the years by counting the number of movies released each year and visualizing it using a plot.

# %%
#Yearly Trend
yearly_counts = dataset1.groupby('Year')['Title'].count()

# Plotting the line plot
plt.figure(figsize=(12, 6))
plt.plot(yearly_counts.index, yearly_counts.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Yearly Trend of Movies')
plt.grid(True)
plt.show()

# %% [markdown]
# From The above chart we can see that the production of movies has decreased greatly over the years

# %% [markdown]
# Genre and Year Relationship: Next we will explore the relationship between genres and the year of release using a stacked bar chart.

# %%
# Group the dataset by year and count the number of movies for each genre

# Group the dataset by genre and year and count the number of movies
genre_year_counts = dataset1.groupby(['Genre', 'Year']).size().unstack().fillna(0)

# Plotting the grouped bar chart
genre_year_counts.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Genre Distribution by Year')
plt.legend(title='Genre')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### b) Exploratory Analysis On Dataset2

# %%
dataset2
# Out:
#                                         Movie Title Original Language
# 0      Harry Potter and the Deathly Hallows: Part 1                en  \
# 1                          How to Train Your Dragon                en
# 2                                        Iron Man 2                en
# 3                                         Toy Story                en
# 4                                         Inception                en
# ...                                             ...               ...
# 26512                         Laboratory Conditions                en
# 26513                               _EXHIBIT_84xxx_                en
# 26514                                  The Last One                en
# 26515                                  Trailer Made                en
# 26516                                    The Church                en
#
#       Release Date  Popularity
# 0       2010-11-19      33.533
# 1       2010-03-26      28.734
# ...

# %%
 #Exploring the distribution of movie popularity.
plt.hist(dataset2['Popularity'], bins=20)
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.title('Distribution of Movie Popularity')
plt.show()

# %% [markdown]
# Most of the Movies in the Dataset are Unpopular

# %%
#Analysis of  the language distribution.
top_languages = language_counts.head(10)  # Select the top 10 dominant languages

plt.bar(top_languages.index, top_languages.values)
plt.xlabel('Original Language')
plt.ylabel('Count')
plt.title('Top 10 Dominant Languages')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can conclude that the most dominant language is English in movie production

# %%
 #Examining the release date pattern.
dataset2['Release Date'] = pd.to_datetime(dataset2['Release Date'])
dataset2['Year'] = dataset2['Release Date'].dt.year

yearly_counts = dataset2['Year'].value_counts().sort_index()

plt.plot(yearly_counts.index, yearly_counts.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Yearly Distribution of Movies')
plt.grid(True)
plt.show()

# %%
# Select the top 10 popular movies
top_10_movies = dataset2.nlargest(10, 'Popularity')

# Extract movie titles and popularity values
movies = top_10_movies['Movie Title']
popularity = top_10_movies['Popularity']

# Create a bar graph
plt.bar(movies, popularity)
plt.xlabel('Movie')
plt.ylabel('Popularity')
plt.title('Top 10 Popular Movies')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### c) Exploratory Analysis On Dataset3

# %%
dataset3
# Out:
#                                             Movie Release Date
# 0                                          Avatar   2009-12-18  \
# 1     Pirates of the Caribbean: On Stranger Tides   2011-05-20
# 2                                    Dark Phoenix   2019-06-07
# 3                         Avengers: Age of Ultron   2015-05-01
# 4               Star Wars Ep. VIII: The Last Jedi   2017-12-15
# ...                                           ...          ...
# 5777                                       Red 11   2018-12-31
# 5778                                    Following   1999-04-02
# 5779                Return to the Land of Wonders   2005-07-13
# 5780                         A Plague So Pleasant   2015-09-29
# 5781                            My Date With Drew   2005-08-05
#
#       Production Budget  Domestic Gross  Worldwide Gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# ...

# %%
# Calculating  profit and return on investment (ROI):
dataset3['Profit'] = dataset3['Worldwide Gross'] - dataset3['Production Budget']
dataset3['ROI'] = (dataset3['Profit'] / dataset3['Production Budget']) * 100

# %%
#Visualizing  the distribution of the numeric columns:
plt.figure(figsize=(10, 6))
plt.hist(dataset3['Production Budget'], bins=10, edgecolor='black')
plt.xlabel('Production Budget')
plt.ylabel('Frequency')
plt.title('Distribution of Production Budget')
plt.show()

# %%
#Analyzing the relationship between variables:
plt.scatter(dataset3['Production Budget'], dataset3['Worldwide Gross'])
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.title('Production Budget vs. Movie Revenue')
plt.savefig('budget_revenue.png')
plt.show()

# %%
#calculating correlation coefficients
correlation_matrix = dataset3[['Production Budget', 'Domestic Gross', 'Worldwide Gross', 'Profit', 'ROI']].corr()
print(correlation_matrix)
# Out:
#                    Production Budget  Domestic Gross  Worldwide Gross
# Production Budget           1.000000        0.685682         0.748306  \
# Domestic Gross              0.685682        1.000000         0.938853
# Worldwide Gross             0.748306        0.938853         1.000000
# Profit                      0.608752        0.926605         0.981811
# ROI                        -0.048715        0.062669         0.047238
#
#                      Profit       ROI
# Production Budget  0.608752 -0.048715
# Domestic Gross     0.926605  0.062669
# Worldwide Gross    0.981811  0.047238
# Profit             1.000000  0.070439
# ROI                0.070439  1.000000

# %%
#Exploring trends over time
dataset3['Release Year'] = pd.to_datetime(dataset3['Release Date']).dt.year

average_budget_by_year = dataset3.groupby('Release Year')['Production Budget'].mean()
average_gross_by_year = dataset3.groupby('Release Year')['Worldwide Gross'].mean()

plt.plot(average_budget_by_year.index, average_budget_by_year.values, label='Average Production Budget')
plt.plot(average_gross_by_year.index, average_gross_by_year.values, label='Average Worldwide Gross')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Average Production Budget and Worldwide Gross by Year')
plt.legend()
plt.show()

# %%
 #Identifying top-performing movies
top_grossing_movies = dataset3.sort_values('Worldwide Gross', ascending=False).head(10)
top_grossing_movies
# Out:
#                                              Movie Release Date
# 0                                           Avatar   2009-12-18  \
# 42                                         Titanic   1997-12-19
# 5             Star Wars Ep. VII: The Force Awakens   2015-12-18
# 6                           Avengers: Infinity War   2018-04-27
# 33                                  Jurassic World   2015-06-12
# 66                                       Furious 7   2015-04-03
# 26                                    The Avengers   2012-05-04
# 3                          Avengers: Age of Ultron   2015-05-01
# 41                                   Black Panther   2018-02-16
# 260  Harry Potter and the Deathly Hallows: Part II   2011-07-15
#
#      Production Budget  Domestic Gross  Worldwide Gross      Profit
# 0            425000000       760507625       2776345279  2351345279  \
# 42           200000000       659363944       2208208395  2008208395
# ...

# %%
# Barchart showing the Top Grossing Movies
plt.figure(figsize=(10, 6))
plt.bar(top_grossing_movies['Movie'], top_grossing_movies['Worldwide Gross'])
plt.xlabel('Movie')
plt.ylabel('Worldwide Gross')
plt.title('Top Grossing Movies')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 6. Summary of the analysis
# > Based on the analysis conducted on the box office data, here are the conclusions and actionable insights for Microsoft's new movie studio:

# %% [markdown]
# 1. Genres: Documentary, Drama, Comedy, Action, Adventure, and Horror genres tend to perform exceptionally well at the box office, generating higher revenues and popularity. These genres have a broad appeal and attract a large audience.

# %%
#Visualizing the frequency distribution of genres
genre_counts = dataset1['Genre'].value_counts()
plt.figure(figsize=(8, 4))
plt.bar(genre_counts.index, genre_counts.values)
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Genre Frequency Distribution')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2. Franchise Films: Movies based on established franchises, such as superhero films or popular book adaptations, have demonstrated significant success. Consider acquiring rights to well-known franchises or creating films that can potentially develop into successful franchises.

# %%
# Select the top 10 popular movies
top_10_movies = dataset2.nlargest(10, 'Popularity')

# Extract movie titles and popularity values
movies = top_10_movies['Movie Title']
popularity = top_10_movies['Popularity']

# Create a bar graph
plt.bar(movies, popularity)
plt.xlabel('Movie')
plt.ylabel('Popularity')
plt.title('Top 10 Popular Movies')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3. In terms of language, it is essential to consider the language preferences of the target audience and the global market. While English has been the dominant language in the film industry, exploring films in other languages can open up opportunities to tap into different markets and reach a broader audience.

# %%
 #Analysis of  the language distribution.
top_languages = language_counts.head(10)  # Select the top 10 dominant languages

plt.bar(top_languages.index, top_languages.values)
plt.xlabel('Original Language')
plt.ylabel('Count')
plt.title('Top 10 Dominant Languages')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# International Market: With the growth of international markets, consider producing films in languages other than English to cater to specific regions or countries. This can help capture local audiences and expand the studio's global reach.

# %% [markdown]
# 4. Release Strategy: Plan strategic release dates, considering peak movie seasons and avoiding major competition from other blockbuster films. Release films during holidays, summer seasons, or specific periods when the target audience is more likely to visit theaters.

# %%
# Convert the 'Release Date' column to datetime format
dataset3['Release Date'] = pd.to_datetime(dataset3['Release Date'])
# Group the movies by year and count the number of releases
release_counts = dataset3.groupby(dataset3['Release Date'].dt.year)['Movie'].count()
# Plotting the graph
plt.figure(figsize=(8, 4))
release_counts.plot(kind='line', marker='o')
# Set the labels and title
plt.xlabel('Year')
plt.ylabel('Number of Movie Releases')
plt.title('Release Strategy: Number of Movie Releases Over Time')
plt.savefig('release_strategy.png')
# Show the plot
plt.show()

# %% [markdown]
# 3. Budget Allocation: Allocate a substantial production budget for high-quality visual effects, captivating storytelling, and immersive cinematic experiences. Big-budget films often attract audiences and generate substantial box office revenues.

# %%
#Exploring trends over time
dataset3['Release Year'] = pd.to_datetime(dataset3['Release Date']).dt.year

average_budget_by_year = dataset3.groupby('Release Year')['Production Budget'].mean()
average_gross_by_year = dataset3.groupby('Release Year')['Worldwide Gross'].mean()

plt.plot(average_budget_by_year.index, average_budget_by_year.values, label='Average Production Budget')
plt.plot(average_gross_by_year.index, average_gross_by_year.values, label='Average Worldwide Gross')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Average Production Budget and Worldwide Gross by Year')
plt.legend()
plt.show()

# %%
dataset3['Decade'] = dataset3['Release Date'].dt.year // 10 * 10

# Group the data by decade and calculate the total worldwide gross revenue
decade_revenue = dataset3.groupby('Decade')['Worldwide Gross'].sum()

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(decade_revenue.index.astype(str), decade_revenue.values)
plt.xlabel('Decade')
plt.ylabel('Total Worldwide Gross Revenue')
plt.title('Revenue Distribution by Decade')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 4. Box Office Performance: The top performing movies in the industry have consistently achieved high box office revenues, both domestically and worldwide. These movies have resonated with a large audience and have generated significant financial success.
#
#
#     A closer look at the top performing movies reveals some common traits. Many of these movies belong to popular genres such as action, adventure, superhero, or fantasy. They often feature compelling storytelling, high production values, and visually stunning effects. Successful movies have also tapped into the nostalgia factor, reimagining beloved franchises or adapting popular books.

# %%
# Barchart showing the Top Grossing Movies
plt.figure(figsize=(8, 4))
plt.bar(top_grossing_movies['Movie'], top_grossing_movies['Worldwide Gross'])
plt.xlabel('Movie')
plt.ylabel('Worldwide Gross')
plt.title('Top performing  Movies')
plt.xticks(rotation=90)
plt.savefig('Box_Office_Performance.png')
plt.show()

# %%
movies = ['Avatar', 'Pirates of the Caribbean: On Stranger Tides', 'Dark Phoenix', 'Avengers: Age of Ultron', 'Star Wars Ep. VIII: The Last Jedi']
worldwide_gross = [2776345279, 1045663875, 149762350, 1403013963, 1316721747]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(movies, worldwide_gross, color='blue')
plt.xlabel('Movies')
plt.ylabel('Worldwide Gross (in billions)')
plt.title('Top Performing Movies - Worldwide Gross')
plt.xticks(rotation=45)

# Add data labels
for i, v in enumerate(worldwide_gross):
    plt.text(i, v, str(v), ha='center', va='bottom')

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the analysis, it is evident that audiences gravitate towards movies that provide a captivating cinematic experience, whether through immersive storytelling, stunning visuals, or emotional depth. Genres like action, adventure, and superhero movies have proven to be highly successful, attracting a broad audience.
